# %% [markdown]
# <a href="https://colab.research.google.com/github/coderaadi1/ML_using_tensorflow/blob/main/Bagging_with_random_data(decision%20tree%20classifier).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
data = datasets.load_wine(as_frame = True)

# %%
x = data.data
y = data.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.25,random_state = 22)

# %%
dtree = DecisionTreeClassifier(random_state = 22)
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=22)

# %%
y_pred = dtree.predict(x_test)

print("Train Dtat accuracy:",accuracy_score(y_true = y_train, y_pred = dtree.predict(x_train)))
print("Test data accuracy:",accuracy_score(y_true = y_test, y_pred = y_pred))
# Out:
# Train Dtat accuracy: 1.0
# Test data accuracy: 0.8222222222222222

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import BaggingClassifier

# %%
data = datasets.load_wine(as_frame = True)

# %%
x = data.data
y = data.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 22)

# %%
n_tree = [2,4,6,8,10,12,14,16]
models = []
scores = []

# %%
for n_estimators in n_tree:
  clf = BaggingClassifier(n_estimators = n_estimators , random_state = 22)

  clf.fit(x_train, y_train)

  models.append(clf)
  scores.append(accuracy_score(y_true = y_test,y_pred = clf.predict(x_test)))

plt.figure(figsize = (9,6))
plt.plot(n_tree, scores)
plt.xlabel("n_tree", fontsize = 18)
plt.ylabel("score", fontsize = 18)
plt.tick_params(labelsize = 16)

plt.show()
